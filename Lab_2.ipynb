# %%
x=int(input('Введіть значення х:'))
a=-2
b=0
c=2
d=5
def add(x,a,b,c,d): 
  if a<=x<=b:
    y=(x-a)/(b-a)
  if b<=x<=c:
    y=1
  if c<=x<=d:
    y=(d-x)/(d-c)
  if d<=x or x<=a:
    y=0
  return y  
print('Значення функції: ',add(x,a,b,c,d))
# Out:
# Введіть значення х:4
# Значення функції:  0.3333333333333333

# %%
x=float(input('Введіть значення х:'))
y=float(input('Введіть значення y:'))

if (0<=y<=1) and (-1<=x<=0) and (y>=-x):
  print('Точка належить заданій області')
elif (0<=y<=1) and (0<=x<=1) and (y>=x*x):
  print('Точка належить заданій області')
else:
  print('Точка не належить заданій області')
# Out:
# Введіть значення х:0.5
# Введіть значення y:0.7
# Точка належить заданій області

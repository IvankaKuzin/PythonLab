# %%
from random import uniform
n=int(input('К-сть стовпців: '))
m=int(input('К-сть рядків: '))
data=[[uniform(-10,10) for i in range(0,n)] for j in range(0,m)]
print ("Утворений масив: ")
for i in data:
    for j in i:
      print('{:^10}'.format('{:.2f}'.format(j)),end=" ")
    print()

min_el=10
for i in range(len(data)):
  for j in range(len(data[i])):
    if data[i][j]>0 and data[i][j]<min_el:
      min_el=data[i][j]
      min_i=i
      min_j=j
print('Мінімальний додатній елемент: ','{:.2f}'.format(min_el))

for i in range(len(data)):
    p=data[i][min_j]
    data[i][min_j]=data[i][n-1]
    data[i][n-1]=p
print ("Змінений масив: ")
for i in data:
    for j in i:
        print('{:^10}'.format('{:.2f}'.format(j)),end=" ")
    print()
# Out:
# К-сть стовпців: 5
# К-сть рядків: 3
# Утворений масив:
#    3.32      -8.05      -1.30       5.96      -8.62
#    3.11      -3.65       2.18       1.63      -6.94
#   -4.98       5.03       8.70      -3.15      -0.19
# Мінімальний додатній елемент:  1.63
# Змінений масив:
#    3.32      -8.05      -1.30      -8.62       5.96
#    3.11      -3.65       2.18      -6.94       1.63
#   -4.98       5.03       8.70      -0.19      -3.15

# %%
house=[
    ('Петренко Іван','Івасюка15','Школа 10',8) ,
    ('Коваленко Микола','СічовихСтрільців41','Школа 8',10),
    ('Миколенко Андрій','Франка105','Школа 2',6),
    ('Андріїв Святослав','Шевченка29','Школа 18',11),
    ('Бук Ольга','Городоцька128','Школа 10',9),
    ('Капуста Олег','Пластова42','Школа 10',10),
    ('Гнатів Ігор','Виговського16','Школа 8',11),
    ('Кухар Людмила','Наукова105','Школа 12',9),
    ('Гриб Наталя','Художня18','Школа 1',7),
    ('Сотник Софія','Городоцька45','Школа 5',8)
]
clas1 = 10
clas2 = 11
slist = []
k = 0;
school = input("Введіть школу: ")
for i in house:
  slist.append([])
  if school in i:
    if clas1 in i:
      slist[k].append(i[0])
      slist[k].append(i[1])
      slist[k].append(i[3])
      k += 1
    elif clas2 in i:
      slist[k].append(i[0])
      slist[k].append(i[1])
      slist[k].append(i[3])
      k += 1
tuple1 = tuple(slist)
for i in range(k):
  print(slist[i])
# Out:
# Введіть школу: Школа 8
# ['Коваленко Микола', 'СічовихСтрільців41', 10]
# ['Гнатів Ігор', 'Виговського16', 11]

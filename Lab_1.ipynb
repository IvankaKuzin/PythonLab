# %%
kil=int(input())
pl=int(input())
gust=kil/pl
print(gust)
# Out:
# 145000
# 9
# 16111.111111111111

# %%
a=int(input())
b=int(input())
sum=a+b
riz=a-b
dob=a*b
dil=a/b
print(sum,riz,dob,dil)
# Out:
# 8
# 2
# 10 6 16 4.0

# %%
chuslo=input()
x=int(chuslo[0])*int(chuslo[1])*int(chuslo[2])
print(x)
# Out:
# 134
# 12

# %%
x=int(input())
y=int(input())
if x>=2:
  if y>=1 or y<=-1.5:
    print(True)
  else:
    print(False)
else:
  print(False)
